# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("Customer Churn.csv")
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.tail()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   str
#  1   gender            7043 non-null   str
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   str
#  4   Dependents        7043 non-null   str
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   str
#  7   MultipleLines     7043 non-null   str
#  8   InternetService   7043 non-null   str
#  9   OnlineSecurity    7043 non-null   str
#  10  OnlineBackup      7043 non-null   str
#  11  DeviceProtection  7043 non-null   str
#  12  TechSupport       7043 non-null   str
#  13  StreamingTV       7043 non-null   str
#  14  StreamingMovies   7043 non-null   str
#  15  Contract          7043 non-null   str
#  16  PaperlessBilling  7043 non-null   str
# ...

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
df["Churn"].value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
df["Churn"].value_counts(normalize=True) * 100
# Out:
# Churn
# No     73.463013
# Yes    26.536987
# Name: proportion, dtype: float64

# %%
df.isnull()
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0          False   False          False    False       False   False
# 1          False   False          False    False       False   False
# 2          False   False          False    False       False   False
# 3          False   False          False    False       False   False
# 4          False   False          False    False       False   False
# ...          ...     ...            ...      ...         ...     ...
# 7038       False   False          False    False       False   False
# 7039       False   False          False    False       False   False
# 7040       False   False          False    False       False   False
# 7041       False   False          False    False       False   False
# 7042       False   False          False    False       False   False
#
#       PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# ...

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# customerID              str
# gender                  str
# SeniorCitizen         int64
# Partner                 str
# Dependents              str
# tenure                int64
# PhoneService            str
# MultipleLines           str
# InternetService         str
# OnlineSecurity          str
# OnlineBackup            str
# DeviceProtection        str
# TechSupport             str
# StreamingTV             str
# StreamingMovies         str
# Contract                str
# PaperlessBilling        str
# PaymentMethod           str
# MonthlyCharges      float64
# TotalCharges            str
# Churn                   str
# dtype: object

# %%
df["TotalCharges"].dtype
# Out:
# <StringDtype(na_value=nan)>

# %%
df["TotalCharges"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["TotalCharges"].head(10)
# Out:
# 0      29.85
# 1     1889.5
# 2     108.15
# 3    1840.75
# 4     151.65
# 5      820.5
# 6     1949.4
# 7      301.9
# 8    3046.05
# 9    3487.95
# Name: TotalCharges, dtype: str

# %%
df["TotalCharges"].value_counts().tail()
# Out:
# TotalCharges
# 1990.5    1
# 7362.9    1
# 346.45    1
# 306.6     1
# 6844.5    1
# Name: count, dtype: int64

# %%
df[df["TotalCharges"].str.strip() ==""].shape
# Out:
# (11, 21)

# %%
df["TotalCharges"] = pd.to_numeric(df["TotalCharges"], errors="coerce")

# %%
df["TotalCharges"].isnull().sum()
# Out:
# np.int64(11)

# %%
df.dropna(subset=["TotalCharges"],inplace=True)

# %%
df.shape
# Out:
# (7032, 21)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.countplot(x="Churn",data=df)

plt.title("Customer Churn Destibution")
plt.xlabel("Churn")
plt.ylabel("Number of Customers")

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.countplot(x="gender",hue="Churn",data=df)

plt.title("Churn by Gender")
plt.xlabel("Gender")
plt.ylabel("Number of Customers")

plt.show()

# %%
gender_Churn = pd.crosstab(
    df["gender"],
    df["Churn"],
    normalize="index")*100

gender_Churn.plot(kind="bar")

plt.title("Churn Percentage by Gender")
plt.xlabel("Gender")
plt.ylabel("Percentage")
plt.xticks(rotation=0)
plt.legend(title="Churn")

plt.show()

# %%
sns.countplot(x="SeniorCitizen",hue="Churn",data=df)

plt.title("Churn by Senior Citizen")
plt.xlabel("Senior Citizen")
plt.ylabel("Number of Customers")

plt.show()

# %%
senior_churn = pd.crosstab(
    df["SeniorCitizen"],
    df["Churn"],
    normalize="index"
)*100

senior_churn
# Out:
# Churn                 No        Yes
# SeniorCitizen
# 0              76.349745  23.650255
# 1              58.318739  41.681261

# %%
sns.countplot(x="Contract", hue="Churn",data=df)

plt.title("Churn by Contract type")
plt.xlabel("Contract Type")
plt.ylabel("Number of Customers")

plt.xticks(rotation=15)

plt.show()

# %%
contract_churn  = pd.crosstab(
    df["Contract"],
    df["Churn"],
    normalize="index"
)*100

contract_churn
# Out:
# Churn                  No        Yes
# Contract
# Month-to-month  57.290323  42.709677
# One year        88.722826  11.277174
# Two year        97.151335   2.848665

# %%
plt.figure(figsize=(8,5))

sns.histplot(data=df,x="tenure",hue="Churn",bins=30,kde=True)

plt.title("Tenure Distribution by Churn")
plt.xlabel("Tenure ((months)")
plt.ylabel("Number of Customers")

plt.show()

# %%
bins=[0,12,24,48,72]
labels=["0-12 Months", "13-24 Months", "25-48 Months", "49-72 Months"]

df["TenureGroup"] = pd.cut(
    df["tenure"],
    bins=bins,
    labels=labels,
    include_lowest=True
)

# %%
tenure_churn = pd.crosstab(
    df["TenureGroup"],
    df["Churn"],
    normalize="index"
    )*100
tenure_churn
# Out:
# Churn                No        Yes
# TenureGroup
# 0-12 Months   52.321839  47.678161
# 13-24 Months  71.289062  28.710938
# 25-48 Months  79.611041  20.388959
# 49-72 Months  90.486824   9.513176

# %%
sns.countplot(x="InternetService",hue="Churn",data=df)

plt.title("Churn by Internet Service")
plt.xlabel("Internet Service")
plt.ylabel("Number of Customers")

plt.show()

# %%
internet_churn = pd.crosstab(
    df["InternetService"],
    df["Churn"],
    normalize="index"
)*100

internet_churn
# Out:
# Churn                   No        Yes
# InternetService
# DSL              81.001656  18.998344
# Fiber optic      58.107235  41.892765
# No               92.565789   7.434211

# %%
sns.countplot(x="PaymentMethod", hue="Churn", data=df)

plt.title("Churn by Payment Method")
plt.xlabel("Payment Method")
plt.ylabel("Number of Customers")
plt.xticks(rotation=30)

plt.show()

# %%
Payment_Churn = pd.crosstab(
    df["PaymentMethod"],
    df["Churn"],
    normalize="index"
)*100

Payment_Churn
# Out:
# Churn                             No        Yes
# PaymentMethod
# Bank transfer (automatic)  83.268482  16.731518
# Credit card (automatic)    84.746877  15.253123
# Electronic check           54.714588  45.285412
# Mailed check               80.798005  19.201995

# %%
sns.countplot(x="TechSupport",hue="Churn",data=df)

plt.title("Churn by Tech Support")
plt.xlabel("Tech Support")
plt.ylabel("Number of Customers")

plt.show()

# %%
Tech_Churn= pd.crosstab(
    df["TechSupport"],
    df["Churn"],
    normalize="index"
)*100

Tech_Churn
# Out:
# Churn                       No        Yes
# TechSupport
# No                   58.352535  41.647465
# No internet service  92.565789   7.434211
# Yes                  84.803922  15.196078

# %%
sns.countplot(x="OnlineSecurity",hue="Churn",data=df)

plt.title("Churn by Online Security")
plt.xlabel("OnlineSecurity")
plt.ylabel("Number of Customers")
plt.xticks(rotation=30)

plt.show()

# %%
Security_Churn= pd.crosstab(
    df["OnlineSecurity"],
    df["Churn"],
    normalize="index"
)*100

Security_Churn
# Out:
# Churn                       No        Yes
# OnlineSecurity
# No                   58.221333  41.778667
# No internet service  92.565789   7.434211
# Yes                  85.359801  14.640199

# %%
sns.countplot(x="OnlineBackup",hue="Churn",data=df)

plt.title("Churn by Online Backup")
plt.xlabel("Online Backup")
plt.ylabel("Number of Customers")
plt.xticks(rotation=15)

plt.show()

# %%
Backup_Churn = pd.crosstab(
    df["OnlineBackup"],
    df["Churn"],
    normalize="index"
) * 100

Backup_Churn
# Out:
# Churn                       No        Yes
# OnlineBackup
# No                   60.058309  39.941691
# No internet service  92.565789   7.434211
# Yes                  78.432990  21.567010

# %%
sns.countplot(x="DeviceProtection",hue="Churn",data=df)

plt.title("Churn by Device Protection")
plt.xlabel("Device Protection")
plt.ylabel("Number of Customers")
plt.xticks(rotation=15)

plt.show()

# %%
DeviceProtection_Churn = pd.crosstab(
    df["DeviceProtection"],
    df["Churn"],
    normalize="index"
) * 100

DeviceProtection_Churn
# Out:
# Churn                       No        Yes
# DeviceProtection
# No                   60.859729  39.140271
# No internet service  92.565789   7.434211
# Yes                  77.460711  22.539289

# %%
sns.countplot(x="PaperlessBilling", hue="Churn", data=df)

plt.title("Churn by Paperless Billing")
plt.xlabel("Paperless Billing")
plt.ylabel("Number of Customers")

plt.show()

# %%
PaperlessBilling_Churn= pd.crosstab(
    df["PaperlessBilling"],
    df["Churn"],
    normalize="index"
) * 100

PaperlessBilling_Churn
# Out:
# Churn                    No        Yes
# PaperlessBilling
# No                83.624302  16.375698
# Yes               66.410749  33.589251

# %%
sns.boxplot(x="Churn",y="MonthlyCharges",data=df)

plt.title("Monthly Charges by Churn ")
plt.xlabel("Churn")
plt.ylabel("Monthly Charges ")

plt.show()

# %%
df.groupby("Churn")["MonthlyCharges"].mean()
# Out:
# Churn
# No     61.307408
# Yes    74.441332
# Name: MonthlyCharges, dtype: float64

# %%
sns.boxplot(x="Churn", y="TotalCharges", data=df)

plt.title("Total Charges by Churn")
plt.xlabel("Churn")
plt.ylabel("Total Charges")

plt.show()

# %%
df.groupby("Churn")["TotalCharges"].mean()
# Out:
# Churn
# No     2555.344141
# Yes    1531.796094
# Name: TotalCharges, dtype: float64

# %%
partner_churn = pd.crosstab(
    df["Partner"],
    df["Churn"],
    normalize="index"
) * 100

partner_churn
# Out:
# Churn           No        Yes
# Partner
# No       67.023908  32.976092
# Yes      80.282935  19.717065

# %%
dependents_churn = pd.crosstab(
    df["Dependents"],
    df["Churn"],
    normalize="index"
) * 100

dependents_churn
# Out:
# Churn              No        Yes
# Dependents
# No          68.720860  31.279140
# Yes         84.468795  15.531205

# %%
contract_internet_churn = pd.crosstab(
    [df["Contract"],df["InternetService"]],
    df["Churn"],
    normalize="index"
) * 100

contract_internet_churn
# Out:
# Churn                                  No        Yes
# Contract       InternetService
# Month-to-month DSL              67.784137  32.215863
#                Fiber optic      45.394737  54.605263
#                No               81.106870  18.893130
# One year       DSL              90.701754   9.298246
#                Fiber optic      80.705009  19.294991
#                No               97.520661   2.479339
# Two year       DSL              98.073836   1.926164
#                Fiber optic      92.773893   7.226107
#                No               99.210111   0.789889

# %%
high_risk = df[
    (df["Contract"] == "Month-to-month") &
    (df["InternetService"] == "Fiber optic")
    ]

high_risk.shape
# Out:
# (2128, 22)

# %%
high_risk["Churn"].value_counts()
# Out:
# Churn
# Yes    1162
# No      966
# Name: count, dtype: int64

# %%
high_risk["Churn"].value_counts(normalize=True)*100
# Out:
# Churn
# Yes    54.605263
# No     45.394737
# Name: proportion, dtype: float64

# %%
high_risk_payment =pd.crosstab(
    high_risk["PaymentMethod"],
    high_risk["Churn"],
    normalize="index"
) * 100

high_risk_payment
# Out:
# Churn                             No        Yes
# PaymentMethod
# Bank transfer (automatic)  54.434251  45.565749
# Credit card (automatic)    58.361775  41.638225
# Electronic check           39.632747  60.367253
# Mailed check               49.253731  50.746269

# %%
df.groupby("Churn")["MonthlyCharges"].mean()
# Out:
# Churn
# No     61.307408
# Yes    74.441332
# Name: MonthlyCharges, dtype: float64

# %%
churn_rate= df["Churn"].value_counts(normalize=True)*100
churn_rate
# Out:
# Churn
# No     73.421502
# Yes    26.578498
# Name: proportion, dtype: float64

# %%
summary = pd.DataFrame({
    "Metric": [
        "Overall Churn Rate",
        "High Risk Customers",
        "High-Risk Churn Rate",
        "Average Monthly Charges - Churned",
        "Average Monthly Charges - Non Churned"
    ],
    "Value": [
        churn_rate["Yes"],
        len(high_risk),
        high_risk["Churn"].value_counts(normalize=True)["Yes"] * 100,
        df.groupby("Churn")["MonthlyCharges"].mean()["Yes"],
        df.groupby("Churn")["MonthlyCharges"].mean()["No"]
    ]
})

summary
# Out:
#                                   Metric        Value
# 0                     Overall Churn Rate    26.578498
# 1                    High Risk Customers  2128.000000
# 2                   High-Risk Churn Rate    54.605263
# 3      Average Monthly Charges - Churned    74.441332
# 4  Average Monthly Charges - Non Churned    61.307408

# %%
factors= {
    "Month-to-month Contract": 42.71,
    "Fiber Optic Internet": 41.89,
    "Electronic Check": 45.29,
    "No Tech Support": 41.64,
    "No Online Security": 41.77,
    "Paperless Billing": 33.57
}

plt.figure(figsize=(10,5))

plt.bar(factors.keys(),factors.values())

plt.title("Top Customer Churn Factors")
plt.xlabel("Factor")
plt.ylabel("Churn Rate (%)")

plt.xticks(rotation=30,ha="right")
plt.tight_layout()

plt.show()

# %%
# final business insights

insights = {
    "Overall Churn Rate": "26.58% of customers have churned.",
    "Highest Risk Group": "Month-to-month + Fiber optic customers have 54.61% churn.",
    "Payment Risk": "Electronic check customers have 60.37% churn in the high-risk group.",
    "Support Risk": "Customers without Tech Support show higher churn.",
    "Security Risk": "Customers without Online Security show higher churn.",
    "Billing Risk": "Paperless billing customers have 33.57% churn.",
    "Pricing Insight": "Churned customers have higher average monthly charges ($74.44)."
}

for key, value in insights.items():
    print(f"{key}: {value}")
# Out:
# Overall Churn Rate: 26.58% of customers have churned.
# Highest Risk Group: Month-to-month + Fiber optic customers have 54.61% churn.
# Payment Risk: Electronic check customers have 60.37% churn in the high-risk group.
# Support Risk: Customers without Tech Support show higher churn.
# Security Risk: Customers without Online Security show higher churn.
# Billing Risk: Paperless billing customers have 33.57% churn.
# Pricing Insight: Churned customers have higher average monthly charges ($74.44).

# %%
recommendations = [
    "1. Focus on month-to-month customers and encourage them to switch to one-year or two-year contracts.",
    "2. Target month-to-month Fiber optic customers with special retention offers.",
    "3. Encourage customers to use automatic payment methods instead of electronic checks.",
    "4. Provide Tech Support and Online Security services to reduce customer churn.",
    "5. Review pricing for customers with high monthly charges and offer suitable discounts or plans.",
    "6. Offer personalized retention campaigns to customers identified as high-risk."
]

for recommendation in recommendations:
    print(recommendation)
# Out:
# 1. Focus on month-to-month customers and encourage them to switch to one-year or two-year contracts.
# 2. Target month-to-month Fiber optic customers with special retention offers.
# 3. Encourage customers to use automatic payment methods instead of electronic checks.
# 4. Provide Tech Support and Online Security services to reduce customer churn.
# 5. Review pricing for customers with high monthly charges and offer suitable discounts or plans.
# 6. Offer personalized retention campaigns to customers identified as high-risk.

# %%
conclusion = """
Conclusion:
The Customer Churn Analysis shows that 26.58% of customers have churned.
Month-to-month customers and Fiber optic users are the highest-risk segments.
Electronic check users also have a very high churn rate.

Customers without Tech Support and Online Security are more likely to churn.
Paperless billing customers show higher churn compared with non-paperless billing customers.
Churned customers also have higher average monthly charges.

The company should focus on long-term contracts, better customer support,
security services, suitable pricing plans, and targeted retention offers
to reduce customer churn.
"""

print(conclusion)
# Out:
# Conclusion:
# The Customer Churn Analysis shows that 26.58% of customers have churned.
# Month-to-month customers and Fiber optic users are the highest-risk segments.
# Electronic check users also have a very high churn rate.
#
# Customers without Tech Support and Online Security are more likely to churn.
# Paperless billing customers show higher churn compared with non-paperless billing customers.
# Churned customers also have higher average monthly charges.
#
# The company should focus on long-term contracts, better customer support,
# security services, suitable pricing plans, and targeted retention offers
# to reduce customer churn.

# %%
# Overall Churn Rate (%)

churn_rate_pct = df["Churn"].value_counts(normalize=True) * 100

churn_rate_pct.plot(
    kind="bar",
    figsize=(7,5)
)

plt.title("Overall Customer Churn Rate")
plt.xlabel("Churn")
plt.ylabel("Churn Rate (%)")
plt.xticks(rotation=0)
plt.ylim(0, 100)

plt.show()

# %%
factors = {
    "Month-to-month Contract": 42.71,
    "Fiber Optic Internet": 41.89,
    "Electronic Check": 45.29,
    "No Tech Support": 41.64,
    "No Online Security": 41.77,
    "Paperless Billing": 33.57
}

plt.figure(figsize=(10,5))

plt.bar(factors.keys(), factors.values())

plt.title("Top Customer Churn Factors")
plt.xlabel("Factor")
plt.ylabel("Churn Rate (%)")

plt.xticks(rotation=30, ha="right")
plt.ylim(0, 50)

for i, value in enumerate(factors.values()):
    plt.text(i, value + 1, f"{value:.2f}%", ha="center")

plt.tight_layout()
plt.show()

# %%
contract_churn= pd.crosstab(
    df["Contract"],
    df["Churn"],
    normalize="index"
) *100

contract_churn
# Out:
# Churn                  No        Yes
# Contract
# Month-to-month  57.290323  42.709677
# One year        88.722826  11.277174
# Two year        97.151335   2.848665

# %%
plt.figure(figsize=(8,5))

plt.bar(contract_churn.index,contract_churn["Yes"])

plt.title("Churn Rate by Contract Type")
plt.xlabel("Contract Type")
plt.ylabel("Churn Rate (%)")

for i, value in enumerate(contract_churn["Yes"]):
    plt.text(i,value + 1 , f"{value:.2f}%",ha="center")

plt.ylim(0,50)
plt.xticks(rotation=15)

plt.show()

# %%
df.groupby("Churn")["tenure"].mean()
# Out:
# Churn
# No     37.650010
# Yes    17.979133
# Name: tenure, dtype: float64

# %%
tenure_churn = pd.crosstab(
    df["TenureGroup"],
    df["Churn"],
    normalize="index"
) * 100

tenure_churn
# Out:
# Churn                No        Yes
# TenureGroup
# 0-12 Months   52.321839  47.678161
# 13-24 Months  71.289062  28.710938
# 25-48 Months  79.611041  20.388959
# 49-72 Months  90.486824   9.513176

# %%
plt.figure(figsize=(8,5))

plt.bar(tenure_churn.index, tenure_churn["Yes"])

plt.title("Churn Rate by Tenure Group")
plt.xlabel("Tenure Group")
plt.ylabel("Churn Rate (%)")

for i, value in enumerate(tenure_churn["Yes"]):
    plt.text(i, value + 1, f"{value:.2f}%", ha="center")

plt.ylim(0, 55)

plt.show()

# %%
final_insights = [
    "Overall customer churn rate is 26.58%.",
    "Month-to-month contract customers have the highest churn rate at 42.71%.",
    "Customers with Fiber optic internet have relatively high churn.",
    "Electronic check users have the highest churn rate among payment methods.",
    "Customers without Tech Support and Online Security show higher churn.",
    "Paperless billing customers have a higher churn rate than non-paperless billing customers.",
    "New customers with 0-12 months tenure have the highest churn rate at 47.68%.",
    "Churned customers have higher average monthly charges ($74.44) than non-churned customers ($61.31)."
]

for i, insight in enumerate(final_insights, 1):
    print(f"{i}. {insight}")
# Out:
# 1. Overall customer churn rate is 26.58%.
# 2. Month-to-month contract customers have the highest churn rate at 42.71%.
# 3. Customers with Fiber optic internet have relatively high churn.
# 4. Electronic check users have the highest churn rate among payment methods.
# 5. Customers without Tech Support and Online Security show higher churn.
# 6. Paperless billing customers have a higher churn rate than non-paperless billing customers.
# 7. New customers with 0-12 months tenure have the highest churn rate at 47.68%.
# 8. Churned customers have higher average monthly charges ($74.44) than non-churned customers ($61.31).

# %%
recommendations = [
    "Encourage month-to-month customers to switch to one-year or two-year contracts.",
    "Provide special retention offers to new customers with 0-12 months tenure.",
    "Encourage customers to use automatic payment methods instead of electronic checks.",
    "Provide Tech Support and Online Security services to reduce customer churn.",
    "Review pricing plans for customers with high monthly charges.",
    "Create personalized retention campaigns for high-risk customers."
]

print("Recommendations:")
for i, recommendation in enumerate(recommendations, 1):
    print(f"{i}. {recommendation}")
# Out:
# Recommendations:
# 1. Encourage month-to-month customers to switch to one-year or two-year contracts.
# 2. Provide special retention offers to new customers with 0-12 months tenure.
# 3. Encourage customers to use automatic payment methods instead of electronic checks.
# 4. Provide Tech Support and Online Security services to reduce customer churn.
# 5. Review pricing plans for customers with high monthly charges.
# 6. Create personalized retention campaigns for high-risk customers.

# %%
conclusion = """
Final Conclusion:

The Customer Churn Analysis shows that 26.58% of customers have churned.
Month-to-month contract customers have the highest churn rate of 42.71%,
while two-year contract customers have a very low churn rate of 2.85%.

Customers with 0-12 months of tenure have the highest churn rate at 47.68%.
Electronic check users also show a high churn rate. Customers without Tech
Support and Online Security are more likely to churn.

Churned customers have higher average monthly charges ($74.44) compared
with non-churned customers ($61.31).

The company should focus on long-term contracts, better customer support,
online security services, suitable pricing plans, and targeted retention
offers to reduce customer churn.
"""

print(conclusion)
# Out:
# Final Conclusion:
#
# The Customer Churn Analysis shows that 26.58% of customers have churned.
# Month-to-month contract customers have the highest churn rate of 42.71%,
# while two-year contract customers have a very low churn rate of 2.85%.
#
# Customers with 0-12 months of tenure have the highest churn rate at 47.68%.
# Electronic check users also show a high churn rate. Customers without Tech
# Support and Online Security are more likely to churn.
#
# Churned customers have higher average monthly charges ($74.44) compared
# with non-churned customers ($61.31).
#
# The company should focus on long-term contracts, better customer support,
# online security services, suitable pricing plans, and targeted retention
# offers to reduce customer churn.

# %%
df.to_csv("customer_churn_final.csv", index=False)

print("Final CSV created successfully!")
# Out:
# Final CSV created successfully!
